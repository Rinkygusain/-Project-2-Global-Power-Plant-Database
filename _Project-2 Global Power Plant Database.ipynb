# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv")

# %%
data
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
data.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %%
data.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
sns.heatmap(data.isnull(),yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
data.drop(['estimated_generation_gwh','other_fuel2','other_fuel3','generation_gwh_2013','geolocation_source','generation_data_source'],axis=1,inplace=True)

# %%
data.drop(['commissioning_year','owner','wepp_id','year_of_capacity_data','generation_gwh_2019','other_fuel1','country','country_long'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (907, 13)

# %%
data.columns
# Out:
# Index(['name', 'gppd_idnr', 'capacity_mw', 'latitude', 'longitude',
#        'primary_fuel', 'source', 'url', 'generation_gwh_2014',
#        'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
#        'generation_gwh_2018'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# name                     0
# gppd_idnr                0
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# source                   0
# url                      0
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459
# dtype: int64

# %%
#replace null value with mode
data['latitude'].fillna(data['latitude'].median(), inplace=True)
data['longitude'].fillna(data['longitude'].median(), inplace=True)
data['generation_gwh_2014'].fillna(data['generation_gwh_2014'].median(), inplace=True)
data['generation_gwh_2015'].fillna(data['generation_gwh_2015'].median(), inplace=True)
data['generation_gwh_2016'].fillna(data['generation_gwh_2016'].median(), inplace=True)
data['generation_gwh_2017'].fillna(data['generation_gwh_2017'].median(), inplace=True)
data['generation_gwh_2018'].fillna(data['generation_gwh_2018'].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# name                   0
# gppd_idnr              0
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# source                 0
# url                    0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# dtype: int64

# %%
data
# Out:
#                              name   gppd_idnr  capacity_mw  latitude  \
# 0                ACME Solar Tower  WRI1020239          2.5   28.1839
# 1             ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663
# 2        AES Saurashtra Windfarms  WRI1026669         39.2   21.9038
# 3                     AGARTALA GT  IND0000001        135.0   23.8712
# 4                    AKALTARA TPP  IND0000002       1800.0   21.9603
# ..                            ...         ...          ...       ...
# 902                  YERMARUS TPP  IND0000513       1600.0   16.2949
# 903  Yelesandra Solar Power Plant  WRI1026222          3.0   12.8932
# 904  Yelisirur wind power project  WRI1026776         25.5   15.2758
# 905                   ZAWAR MINES  WRI1019901         80.0   24.3500
# 906       iEnergy Theni Wind Farm  WRI1026761         16.5    9.9344
#
#      longitude primary_fuel                                source  \
# 0      73.2407        Solar  National Renewable Energy Laboratory
# ...

# %%
#Categorical Data Visualization
data_visualization_nominal=data[['name', 'gppd_idnr', 'capacity_mw', 'latitude', 'longitude',
       'primary_fuel', 'source', 'url', 'generation_gwh_2014',
       'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
       'generation_gwh_2018']].copy()

# %%
data=sns.countplot(x='source',data=data_visualization_nominal)
print(data_visualization_nominal['source'].value_counts())
# Out:
# Central Electricity Authority                519
# CDM                                          124
# Lancosola                                     10
# National Renewable Energy Laboratory           8
# National Thermal Power Corporation (NTPC)      6
#                                             ...
# Astonfield Management Limited                  1
# Grace Industries ltd                           1
# Sahakar Shiromani vasantrao                    1
# Welspun Solar AP Private Limited               1
# West Coast Paper Mills Ltd.                    1
# Name: source, Length: 191, dtype: int64

# %%
data=sns.countplot(x='capacity_mw',data=data_visualization_nominal)
print(data_visualization_nominal['capacity_mw'].value_counts())
# Out:
# 5.0       39
# 10.0      22
# 15.0      20
# 600.0     20
# 1200.0    19
#           ..
# 192.0      1
# 27.3       1
# 26.4       1
# 68.8       1
# 19.7       1
# Name: capacity_mw, Length: 361, dtype: int64

# %%
data=sns.countplot(x='primary_fuel',data=data_visualization_nominal)
print(data_visualization_nominal['primary_fuel'].value_counts())
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %%
data=sns.countplot(x='name',hue='primary_fuel',data=data_visualization_nominal)
print(data_visualization_nominal['name'].value_counts())
# Out:
# JORETHANG LOOP                     1
# Shivasamundra Solar Power Plant    1
# KORADI                             1
# BHIRA TAIL RACE                    1
# UMTRU (NEW)                        1
#                                   ..
# BANDAKHAR TPP                      1
# SABARIGIRI                         1
# N_SAGAR LBC                        1
# NITIN PLANT                        1
# Karur Textile Park Wind Farm       1
# Name: name, Length: 907, dtype: int64

# %%
sns.scatterplot(x="gppd_idnr",y='primary_fuel',data=data)
# Out:
# <AxesSubplot:xlabel='gppd_idnr', ylabel='primary_fuel'>

# %%
sns.scatterplot(x="capacity_mw",y='gppd_idnr',data=data)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='gppd_idnr'>

# %%
sns.scatterplot(x="capacity_mw",y='latitude',data=data)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='latitude'>

# %%
sns.scatterplot(x="primary_fuel",y='latitude',data=data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='latitude'>

# %%
sns.scatterplot(x="capacity_mw",y='longitude',data=data)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='longitude'>

# %%
sns.scatterplot(x="primary_fuel",y='longitude',data=data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='longitude'>

# %%
plt.hist(data['source'],color='green',bins=10)
plt.show()

# %%
sns.scatterplot(x="capacity_mw",y='source',data=data)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='source'>

# %%
sns.scatterplot(x="primary_fuel",y='source',data=data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='source'>

# %%
sns.scatterplot(x="capacity_mw",y='url',data=data)
x="capacity_mw"
y='url'
plt.scatter(x,y,s=1000,c='lightblue')

# %%
sns.scatterplot(x="primary_fuel",y='url',data=data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='url'>

# %%
sns.scatterplot(x="capacity_mw",y='generation_gwh_2014',data=data)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='generation_gwh_2014'>

# %%
sns.scatterplot(x="primary_fuel",y='generation_gwh_2014',data=data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2014'>

# %%
sns.scatterplot(x="primary_fuel",y='generation_gwh_2015',data=data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2015'>

# %%
sns.scatterplot(x="capacity_mw",y='generation_gwh_2015',data=data)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='generation_gwh_2015'>

# %%
sns.scatterplot(x="primary_fuel",y='generation_gwh_2016',data=data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2016'>

# %%
sns.scatterplot(x="capacity_mw",y='generation_gwh_2016',data=data)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='generation_gwh_2016'>

# %%
sns.scatterplot(x="primary_fuel",y='generation_gwh_2017',data=data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2017'>

# %%
sns.scatterplot(x="capacity_mw",y='generation_gwh_2017',data=data)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='generation_gwh_2017'>

# %%
sns.scatterplot(x="primary_fuel",y='generation_gwh_2018',data=data)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2018'>

# %%
sns.scatterplot(x="capacity_mw",y='generation_gwh_2018',data=data)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='generation_gwh_2018'>

# %%
data.columns
# Out:
# Index(['name', 'gppd_idnr', 'capacity_mw', 'latitude', 'longitude',
#        'primary_fuel', 'source', 'url', 'generation_gwh_2014',
#        'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
#        'generation_gwh_2018'],
#       dtype='object')

# %%
sns.displot(data_visualization_continuous['source'],kde=True)

# %%
sns.pairplot(data)

# %%
#encoding dataframe
from sklearn.preprocessing import OrdinalEncoder
data_1=OrdinalEncoder()
for i in data.columns:
    if data[i].dtypes=='object':
        data[i]=data_1.fit_transform(data[i].values.reshape(-1,1))
data
# Out:
#       name  gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  source  \
# 0      0.0      657.0          2.5   28.1839    73.2407           6.0   109.0
# 1      1.0      519.0         98.0   24.7663    74.6090           1.0   174.0
# 2      2.0      853.0         39.2   21.9038    69.3732           7.0    21.0
# 3      3.0        0.0        135.0   23.8712    91.3602           2.0    22.0
# 4      4.0        1.0       1800.0   21.9603    82.4091           1.0    22.0
# ..     ...        ...          ...       ...        ...           ...     ...
# 902  902.0      491.0       1600.0   16.2949    77.3568           1.0    22.0
# 903  903.0      822.0          3.0   12.8932    78.1654           6.0    77.0
# 904  904.0      891.0         25.5   15.2758    75.5811           7.0    21.0
# 905  905.0      539.0         80.0   24.3500    73.7477           1.0    59.0
# 906  906.0      876.0         16.5    9.9344    77.4768           7.0    21.0
#
# ...

# %%
data.describe()
# Out:
#              name   gppd_idnr  capacity_mw    latitude   longitude  \
# count  907.000000  907.000000   907.000000  907.000000  907.000000
# mean   453.000000  453.000000   326.223755   21.227439   77.427103
# std    261.972645  261.972645   590.085456    6.080491    4.815073
# min      0.000000    0.000000     0.000000    8.168900   68.644700
# 25%    226.500000  226.500000    16.725000   17.072000   74.388900
# 50%    453.000000  453.000000    59.200000   21.780000   76.719500
# 75%    679.500000  679.500000   385.250000   25.176450   79.206100
# max    906.000000  906.000000  4760.000000   34.649000   95.408000
#
#        primary_fuel      source         url  generation_gwh_2014  \
# count    907.000000  907.000000  907.000000           907.000000
# mean       3.206174   43.847850   94.469680          1516.689956
# std        2.280652   44.642818   70.381222          2785.604307
# min        0.000000    0.000000    0.000000             0.000000
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.describe(), annot=True, linewidth=.5,linecolor='yellow')
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#                          name  gppd_idnr  capacity_mw  latitude  longitude  \
# name                 1.000000   0.332205     0.060240 -0.134571   0.019222
# gppd_idnr            0.332205   1.000000    -0.335742 -0.105090  -0.378588
# capacity_mw          0.060240  -0.335742     1.000000  0.048790   0.199299
# latitude            -0.134571  -0.105090     0.048790  1.000000   0.035619
# longitude            0.019222  -0.378588     0.199299  0.035619   1.000000
# primary_fuel         0.040753   0.609180    -0.380395 -0.007538  -0.352056
# source              -0.014640   0.416384    -0.242122  0.054324  -0.236623
# url                  0.041917   0.597080    -0.243830 -0.129180  -0.305768
# generation_gwh_2014  0.082439  -0.162784     0.793497  0.057179   0.106855
# generation_gwh_2015  0.071257  -0.177538     0.819676  0.052422   0.123763
# generation_gwh_2016  0.064611  -0.188103     0.853008  0.046267   0.145640
# ...

# %%
data.corr()['primary_fuel'].sort_values()
# Out:
# capacity_mw           -0.380395
# longitude             -0.352056
# generation_gwh_2018   -0.271198
# generation_gwh_2017   -0.263599
# generation_gwh_2016   -0.259708
# generation_gwh_2015   -0.249304
# generation_gwh_2014   -0.240656
# latitude              -0.007538
# name                   0.040753
# source                 0.053613
# url                    0.589886
# gppd_idnr              0.609180
# primary_fuel           1.000000
# Name: primary_fuel, dtype: float64

# %%
data.corr()['capacity_mw'].sort_values()
# Out:
# primary_fuel          -0.380395
# gppd_idnr             -0.335742
# url                   -0.243830
# source                -0.242122
# latitude               0.048790
# name                   0.060240
# longitude              0.199299
# generation_gwh_2014    0.793497
# generation_gwh_2015    0.819676
# generation_gwh_2016    0.853008
# generation_gwh_2017    0.868338
# generation_gwh_2018    0.884840
# capacity_mw            1.000000
# Name: capacity_mw, dtype: float64

# %%
plt.figure(figsize=(15,12))
sns.heatmap(data.corr(), annot=True, linewidth=1,linecolor='yellow')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,10))
data.corr()['capacity_mw'].sort_values(ascending=False).drop(['capacity_mw']).plot(kind='bar',color='purple')
plt.xlabel('Database',fontsize=14)
plt.ylabel('column with target names',fontsize=16)
plt.title('correlation',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,10))
data.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar',color='blue')
plt.xlabel('Database',fontsize=14)
plt.ylabel('column with target names',fontsize=16)
plt.title('correlation',fontsize=20)
plt.show()

# %%
data.shape
# Out:
# (907, 13)

# %%
#to check outliers
import warnings
warnings.filterwarnings("ignore")
collist=data.columns.values
ncol=2
nrows=7
plt.figure(figsize=(nrows,3*nrows))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data[collist[i]])
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(data))
threshold=3
np.where(z>3)
# Out:
# (array([ 15,  15,  15,  15,  15,  71,  80, 143, 143, 143, 143, 143, 143,
#         147, 158, 179, 183, 191, 209, 209, 209, 209, 209, 209, 244, 299,
#         308, 308, 308, 308, 308, 308, 321, 323, 333, 340, 345, 360, 363,
#         364, 364, 364, 364, 364, 364, 375, 416, 427, 482, 482, 493, 493,
#         493, 493, 493, 493, 494, 494, 494, 494, 494, 494, 499, 519, 532,
#         546, 577, 623, 638, 648, 648, 648, 648, 648, 648, 657, 657, 657,
#         657, 657, 657, 661, 669, 689, 695, 695, 695, 695, 695, 695, 721,
#         721, 721, 721, 721, 724, 724, 724, 724, 724, 726, 726, 726, 726,
#         726, 726, 767, 786, 786, 786, 786, 786, 786, 788, 808, 808, 808,
#         808, 808, 808, 818, 832, 847, 870, 871, 879, 880, 880, 880, 880,
#         880, 880, 895, 900]),
#  array([ 2,  9, 10, 11, 12,  6,  6,  2,  8,  9, 10, 11, 12,  2,  8,  4,  4,
#          6,  2,  8,  9, 10, 11, 12,  4,  6,  2,  8,  9, 10, 11, 12,  6,  4,
# ...

# %%
np.abs(zscore(data))<0
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
data_new=data[(z<3).all(axis=1)]
data_new
# Out:
#       name  gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  source  \
# 0      0.0      657.0          2.5   28.1839    73.2407           6.0   109.0
# 1      1.0      519.0         98.0   24.7663    74.6090           1.0   174.0
# 2      2.0      853.0         39.2   21.9038    69.3732           7.0    21.0
# 3      3.0        0.0        135.0   23.8712    91.3602           2.0    22.0
# 4      4.0        1.0       1800.0   21.9603    82.4091           1.0    22.0
# ..     ...        ...          ...       ...        ...           ...     ...
# 902  902.0      491.0       1600.0   16.2949    77.3568           1.0    22.0
# 903  903.0      822.0          3.0   12.8932    78.1654           6.0    77.0
# 904  904.0      891.0         25.5   15.2758    75.5811           7.0    21.0
# 905  905.0      539.0         80.0   24.3500    73.7477           1.0    59.0
# 906  906.0      876.0         16.5    9.9344    77.4768           7.0    21.0
#
# ...

# %%
#to know the percentage loss
loss_data=((907-851)/907)*100
loss_data
# Out:
# 6.174200661521499

# %%
data.skew().sort_values()
# Out:
# latitude              -0.164152
# name                   0.000000
# gppd_idnr              0.000000
# primary_fuel           0.472251
# longitude              1.163320
# url                    1.510537
# source                 1.827373
# capacity_mw            3.123576
# generation_gwh_2018    5.133226
# generation_gwh_2016    5.281953
# generation_gwh_2017    5.315103
# generation_gwh_2014    5.321360
# generation_gwh_2015    5.566773
# dtype: float64

# %%
#distribution plot to check skewness
collist=data.columns.values
ncol=3
nrows=12
plt.figure(figsize=(nrows,5*nrows))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(data[collist[i]])
    plt.tight_layout()

# %%
from scipy import stats
def diagnostic_plots(data_1,variable):
    plt.figure(figsize=(15,6))
    plt.subplot(1,2,1)
    data[variable].hist()
    
    plt.subplot(1,2,2)
    stats.probplot(data_1[variable],dist="norm",plot=plt)
    plt.show()

# %%
data['generation_gwh_2015']=np.log(data['generation_gwh_2015']+1)
diagnostic_plots(data,'generation_gwh_2015')

# %%
data['generation_gwh_2014']=np.log(data['generation_gwh_2014']+1)
diagnostic_plots(data,'generation_gwh_2014')

# %%
data['generation_gwh_2016']=np.log(data['generation_gwh_2016']+1)
diagnostic_plots(data,'generation_gwh_2016')

# %%
data['generation_gwh_2017']=np.log(data['generation_gwh_2017']+1)
diagnostic_plots(data,'generation_gwh_2017')

# %%
data['generation_gwh_2018']=np.log(data['generation_gwh_2018']+1)
diagnostic_plots(data,'generation_gwh_2018')

# %%
data['capacity_mw']=np.log(data['capacity_mw']+1)
diagnostic_plots(data,'capacity_mw')

# %%
data['source']=np.log(data['source']+1)
diagnostic_plots(data,'source')

# %%
data['url']=np.log(data['url']+1)
diagnostic_plots(data,'url')

# %%
data['latitude']=np.log(data['latitude']+1)
diagnostic_plots(data,'latitude')

# %%
data.skew().sort_values()
# Out:
# generation_gwh_2014   -2.221131
# generation_gwh_2017   -1.964385
# generation_gwh_2018   -1.927848
# generation_gwh_2015   -1.892265
# generation_gwh_2016   -1.877184
# latitude              -0.809599
# url                   -0.587997
# name                   0.000000
# gppd_idnr              0.000000
# capacity_mw            0.135454
# primary_fuel           0.472251
# source                 0.866582
# longitude              1.163320
# dtype: float64

# %%
x=data.drop('primary_fuel',axis=1)
y=data['primary_fuel']

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x.skew()
# Out:
# name                  -0.288179
# gppd_idnr             -0.288179
# capacity_mw           -0.071231
# latitude              -0.102226
# longitude              0.002675
# source                 0.085426
# url                    0.177001
# generation_gwh_2014    0.096268
# generation_gwh_2015    0.065088
# generation_gwh_2016    0.028888
# generation_gwh_2017   -0.032799
# generation_gwh_2018   -0.040839
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-2.16561515,  0.79063305, -1.75281133, ..., -0.03168167,
#         -0.01522394, -0.03710625],
#        [-2.14663031,  0.33133539,  0.21380982, ..., -0.03168167,
#         -0.01522394, -0.03710625],
#        [-2.13033981,  1.39746613, -0.26591815, ..., -0.03168167,
#         -0.01522394, -0.03710625],
#        ...,
#        [ 1.54842588,  1.51018594, -0.49763186, ..., -0.03168167,
#         -0.01522394, -0.03710625],
#        [ 1.55136078,  0.39991495,  0.10928612, ..., -0.03168167,
#         -0.01522394, -0.03710625],
#        [ 1.55429474,  1.4658612 , -0.73568999, ..., -0.03168167,
#         -0.01522394, -0.03710625]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr=LogisticRegression()
maxAccu=0
minRs=0
for i in range(0,50):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    predict=lr.predict(x_test)
    acc=accuracy_score(y_test,predict)
    
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
    print("Best Accuracy is:-",maxAccu,"on random state",maxRs)
# Out:
# Best Accuracy is:- 0.7929515418502202 on random state 0
# Best Accuracy is:- 0.7929515418502202 on random state 0
# Best Accuracy is:- 0.7929515418502202 on random state 0
# Best Accuracy is:- 0.7929515418502202 on random state 0
# Best Accuracy is:- 0.7929515418502202 on random state 0
# Best Accuracy is:- 0.7929515418502202 on random state 0
# Best Accuracy is:- 0.7929515418502202 on random state 0
# Best Accuracy is:- 0.7929515418502202 on random state 0
# Best Accuracy is:- 0.7929515418502202 on random state 0
# Best Accuracy is:- 0.8061674008810573 on random state 9
# Best Accuracy is:- 0.8061674008810573 on random state 9
# Best Accuracy is:- 0.8061674008810573 on random state 9
# Best Accuracy is:- 0.8061674008810573 on random state 9
# Best Accuracy is:- 0.8061674008810573 on random state 9
# Best Accuracy is:- 0.8061674008810573 on random state 9
# Best Accuracy is:- 0.8061674008810573 on random state 9
# Best Accuracy is:- 0.8061674008810573 on random state 9
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
dtc.fit(x_test,y_test)
preddtc=dtc.predict(x_test)
print("Accuracy",accuracy_score(y_test,predict)*100)
print(classification_report(y_test,predict))
print(confusion_matrix(y_test,predict))
# Out:
# Accuracy 20.704845814977972
#               precision    recall  f1-score   support
#
#          0.0       0.14      0.20      0.17        10
#          1.0       0.26      0.35      0.30        63
#          2.0       0.00      0.00      0.00        19
#          3.0       0.19      0.23      0.21        53
#          4.0       0.00      0.00      0.00         3
#          5.0       0.00      0.00      0.00         7
#          6.0       0.13      0.11      0.12        37
#          7.0       0.23      0.20      0.22        35
#
#     accuracy                           0.21       227
#    macro avg       0.12      0.14      0.13       227
# weighted avg       0.18      0.21      0.19       227
#
# [[ 2  4  1  3  0  0  0  0]
#  [ 5 22  1 17  0  1  6 11]
#  [ 3  6  0  4  0  0  4  2]
#  [ 3 22  0 12  0  1 10  5]
#  [ 0  1  0  2  0  0  0  0]
#  [ 0  2  0  2  0  0  1  2]
#  [ 1 16  0 13  0  0  4  3]
#  [ 0 11  1 10  0  0  6  7]]

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
rfc.fit(x_test,y_test)
predrfc=rfc.predict(x_test)
print("Accuracy",accuracy_score(y_test,predict)*100)
print(classification_report(y_test,predict))
print(confusion_matrix(y_test,predict))
# Out:
# Accuracy 20.704845814977972
#               precision    recall  f1-score   support
#
#          0.0       0.14      0.20      0.17        10
#          1.0       0.26      0.35      0.30        63
#          2.0       0.00      0.00      0.00        19
#          3.0       0.19      0.23      0.21        53
#          4.0       0.00      0.00      0.00         3
#          5.0       0.00      0.00      0.00         7
#          6.0       0.13      0.11      0.12        37
#          7.0       0.23      0.20      0.22        35
#
#     accuracy                           0.21       227
#    macro avg       0.12      0.14      0.13       227
# weighted avg       0.18      0.21      0.19       227
#
# [[ 2  4  1  3  0  0  0  0]
#  [ 5 22  1 17  0  1  6 11]
#  [ 3  6  0  4  0  0  4  2]
#  [ 3 22  0 12  0  1 10  5]
#  [ 0  1  0  2  0  0  0  0]
#  [ 0  2  0  2  0  0  1  2]
#  [ 1 16  0 13  0  0  4  3]
#  [ 0 11  1 10  0  0  6  7]]

# %%
x_train_sc=sc.fit_transform(x_train)
x_test_sc=sc.transform(x_test)

# %% [markdown]
# # Support vector classifier

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print("Accuracy",accuracy_score(y_test,predsvc)*100)
print(classification_report(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
# Out:
# Accuracy 80.1762114537445
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.60      0.57        10
#          1.0       0.71      0.90      0.80        63
#          2.0       0.40      0.11      0.17        19
#          3.0       0.79      0.94      0.86        53
#          4.0       0.00      0.00      0.00         3
#          5.0       0.00      0.00      0.00         7
#          6.0       1.00      0.86      0.93        37
#          7.0       0.97      1.00      0.99        35
#
#     accuracy                           0.80       227
#    macro avg       0.55      0.55      0.54       227
# weighted avg       0.75      0.80      0.76       227
#
# [[ 6  4  0  0  0  0  0  0]
#  [ 2 57  0  4  0  0  0  0]
#  [ 0  8  2  9  0  0  0  0]
#  [ 0  3  0 50  0  0  0  0]
#  [ 0  3  0  0  0  0  0  0]
#  [ 1  3  3  0  0  0  0  0]
#  [ 2  2  0  0  0  0 32  1]
#  [ 0  0  0  0  0  0  0 35]]

# %%
#train with standard scaled data
svc2=SVC()
svc2.fit(x_train_sc,y_train)
y_pred_svc_sc=svc2.predict(x_test_sc)
accuracy_score(y_test,y_pred_knn_sc)
# Out:
# 0.7268722466960352

# %% [markdown]
# # K-Nearest Neighbor classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier=KNeighborsClassifier(n_neighbors=5, metric='minkowski',p=2)
knn_classifier.fit(x_train,y_train)
y_pred_knn=knn_classifier.predict(x_test)
accuracy_score(y_test,y_pred_knn)
# Out:
# 0.7312775330396476

# %%
#train with standard scaled data
knn_classifier2=KNeighborsClassifier(n_neighbors=5, metric='minkowski',p=2)
knn_classifier2.fit(x_train_sc,y_train)
y_pred_knn_sc=knn_classifier.predict(x_test_sc)
accuracy_score(y_test,y_pred_knn_sc)
# Out:
# 0.7268722466960352

# %% [markdown]
# # XGBoost Classifier

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier
xgb_classifier=XGBClassifier()
xgb_classifier.fit(x_train,y_train)
y_pred_xgb=xgb_classifier.predict(x_test)
accuracy_score(y_test,y_pred_xgb)
# Out:
# 0.8678414096916299

# %%
#train with standard scaled data
xgb2=XGBClassifier()
xgb2.fit(x_train_sc,y_train)
y_pred_xgb_sc=xgb2.predict(x_test_sc)
accuracy_score(y_test,y_pred_xgb_sc)
# Out:
# 0.8678414096916299

# %%
params={"learning_rate":[0.05,0.10,0.15,0.20,0.25,0.30],
       "max_depth":[3,4,5,6,8,10,12,15],
       "min_child_weight":[1,3,5,7],
       "gamma":[0.1,0.2,0.3,0.4],
       "colsample_bytree":[0.3,0.4,0.5,0.7]}
from sklearn.model_selection import RandomizedSearchCV
random_search=RandomizedSearchCV(xgb_classifier,param_distributions=params,scoring='roc_auc',n_iter=5,n_jobs=-1,verbose=3)
random_search.fit(x_train,y_train)
random_search.best_params_
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# {'min_child_weight': 3,
#  'max_depth': 4,
#  'learning_rate': 0.25,
#  'gamma': 0.2,
#  'colsample_bytree': 0.3}

# %%
random_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.3,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.2, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.25, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=4, max_leaves=0, min_child_weight=3,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...)

# %%
#training XGBoost Classifier with best parameter
xgb=XGBClassifier({'min_child_weight': 7,
 'max_depth': 6,
 'learning_rate': 0.1,
 'gamma': 0.3,
 'colsample_bytree': 0.4})
xgb.fit(x_train,y_train)
y_pred_xgb=xgb.predict(x_test)
accuracy_score(y_test,y_pred_xgb)
# Out:
# 0.8678414096916299

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(xgb,x,y,cv=10)
print("Cv score of XGBoost Classifier is:-",scr.mean()*100)
# Out:
# Cv score of XGBoost Classifier is:- 84.34310134310135

# %%
cm=confusion_matrix(y_test,y_pred_xgb)
plt.title('Heating of Confusion Matrix', fontsize=15)
sns.heatmap(cm,annot=True)
plt.show()

# %%
print(classification_report(y_test,y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.80      0.80        10
#          1.0       0.78      0.90      0.84        63
#          2.0       0.73      0.58      0.65        19
#          3.0       0.93      0.94      0.93        53
#          4.0       0.00      0.00      0.00         3
#          5.0       0.50      0.14      0.22         7
#          6.0       0.95      0.97      0.96        37
#          7.0       0.97      0.97      0.97        35
#
#     accuracy                           0.87       227
#    macro avg       0.71      0.66      0.67       227
# weighted avg       0.85      0.87      0.85       227

# %%
x=data.drop('capacity_mw',axis=1)
y=data['capacity_mw']

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)
x.skew()
# Out:
# name                  -0.053653
# gppd_idnr             -0.053653
# latitude               0.018831
# longitude             -0.008414
# primary_fuel          -0.024434
# source                -0.945049
# url                   -0.410274
# generation_gwh_2014   -0.050372
# generation_gwh_2015   -0.045058
# generation_gwh_2016   -0.037701
# generation_gwh_2017   -0.012233
# generation_gwh_2018   -0.037986
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.93163207,  0.7732363 ,  1.17030283, ..., -0.02547764,
#         -0.01721691, -0.03738244],
#        [-1.91740759,  0.25317928,  0.56235018, ..., -0.02547764,
#         -0.01721691, -0.03738244],
#        [-1.90518411,  1.51476547,  0.06960843, ..., -0.02547764,
#         -0.01721691, -0.03738244],
#        ...,
#        [ 1.70748895,  1.65838222, -0.99144981, ..., -0.02547764,
#         -0.01721691, -0.03738244],
#        [ 1.71126581,  0.32823507,  0.4896103 , ..., -0.02547764,
#         -0.01721691, -0.03738244],
#        [ 1.71504259,  1.60170398, -1.76042967, ..., -0.02547764,
#         -0.01721691, -0.03738244]])

# %%
#Model 1
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.metrics import r2_score
lr=LinearRegression()
for i in range(0,50):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i},the training accuracy is:- {r2_score(y_train,pred_train)}")
    print(f"At random state {i},the training accuracy is:- {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is:- 0.5363586921572242
# At random state 0,the training accuracy is:- 0.5748424942009276
#
#
# At random state 1,the training accuracy is:- 0.555315738611065
# At random state 1,the training accuracy is:- 0.49698611970026285
#
#
# At random state 2,the training accuracy is:- 0.539909849618391
# At random state 2,the training accuracy is:- 0.5615809687467478
#
#
# At random state 3,the training accuracy is:- 0.5505724621995992
# At random state 3,the training accuracy is:- 0.5163107193039209
#
#
# At random state 4,the training accuracy is:- 0.5609159330357171
# At random state 4,the training accuracy is:- 0.46432590363075954
#
#
# At random state 5,the training accuracy is:- 0.5295367901875678
# At random state 5,the training accuracy is:- 0.5984439863514848
#
#
# At random state 6,the training accuracy is:- 0.5626258120472334
# At random state 6,the training accuracy is:- 0.4585277834249494
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=17,test_size=0.20)
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
print(r2_score(y_test,pred_test)*100)
# Out:
# 41.41558033461759

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score 
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold{j},the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing {Test_accuracy}")
    print("\n")
# Out:
# At cross fold2,the cv score is 0.5093289018525025 and accuracy score for training is -0.5562314490955993 and accuracy for the testing 0.41415580334617585
#
#
# At cross fold3,the cv score is 0.5089678329950912 and accuracy score for training is -0.5562314490955993 and accuracy for the testing 0.41415580334617585
#
#
# At cross fold4,the cv score is 0.5093034962190383 and accuracy score for training is -0.5562314490955993 and accuracy for the testing 0.41415580334617585
#
#
# At cross fold5,the cv score is 0.5210931864237874 and accuracy score for training is -0.5562314490955993 and accuracy for the testing 0.41415580334617585
#
#
# At cross fold6,the cv score is 0.5163536143994644 and accuracy score for training is -0.5562314490955993 and accuracy for the testing 0.41415580334617585
#
#
# At cross fold7,the cv score is 0.5089288373518978 and accuracy score for training is -0.5562314490955993 and accuracy for the testing 0.41415580334617585
#
#
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
ls=Lasso()
parameters={'alpha':[.0002,.002,.02,.2,20,200],
           'random_state':list(range(0,20)),
           'max_iter':[500,1000,1500]}
Gs=GridSearchCV(ls,parameters)
Gs.fit(x_train,y_train)
print(Gs.best_params_)
# Out:
# {'alpha': 0.02, 'max_iter': 500, 'random_state': 0}

# %%
ls=Lasso(alpha=0.02,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 57.12314619742933

# %%
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 41.81123611162888

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 52.251992363232304

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
parameter={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
Gscv=GridSearchCV(rf,parameter)
Gscv.fit(x_train,y_train)
print (Gscv.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion="mae",max_features="log2")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 79.50785969543968
# Cross Val Score: 80.91575467569122

# %%
import pickle 
filename= 'Global Power Plant Database'
pickle.dump(rf, open(filename,'wb'))

loaded_model=pickle.load(open('Global Power Plant Database','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 79.50785969543968

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["Predicted","Original"])
conclusion
# Out:
#                0         1         2         3         4         5    \
# Predicted  5.23736  7.067948  6.956784  2.568264  5.400367  4.717683
# Original   5.23736  7.067948  6.956784  2.568264  5.400367  4.717683
#
#                 6         7         8         9    ...       172       173  \
# Predicted  6.299212  2.221209  3.618587  1.914705  ...  7.977752  2.189464
# Original   6.299212  2.221209  3.618587  1.914705  ...  7.977752  2.189464
#
#                 174       175       176       177       178      179  \
# Predicted  5.158019  3.471075  4.314551  5.986667  5.021301  3.45159
# Original   5.158019  3.471075  4.314551  5.986667  5.021301  3.45159
#
#                 180       181
# Predicted  5.913767  6.811638
# Original   5.913767  6.811638
#
# [2 rows x 182 columns]
